# %%
# impor pustaka
# %pip install keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Menyiapkan Data

# %%
# data
data = pd.read_csv('databeasiswa.csv', header=None)
dataset=np.asarray(data)
# split into input (X) and output (Y) variables
X = dataset[1:,1:3]
Y = dataset[1:,3:4]

# %% [markdown]
# ### Membuat Model JST

# %%
# Model JST dengan fungsi
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=2, activation='relu'))
	model.add(Dense(8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %% [markdown]
# ### Proses Validasi Silang

# %%
# Fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# Create the model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation='relu'))  # Adjust input_dim as per your data
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Wrap the model using KerasClassifier
model = KerasClassifier(build_fn=create_model)

# Example data (replace X and Y with your actual dataset)
X = np.random.rand(100, 8)  # Dummy feature data
Y = np.random.randint(2, size=100)  # Dummy labels

# Evaluate using 10-fold cross-validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(model, X, Y, cv=kfold, fit_params={'epochs': 150, 'batch_size': 10, 'verbose': 1})

print("Cross-validation results:", results)
print("Mean accuracy:", results.mean())
# Out:
# E:\Temp\ipykernel_23188\1463930350.py:14: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=150, batch_size=10, verbose=1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 14
#      11     return model
#      13 # Wrap the model using KerasClassifier
# ---> 14 model = KerasClassifier(build_fn=create_model, epochs=150, batch_size=10, verbose=1)
#      16 # Example data (replace X and Y with your actual dataset)
#      17 X = np.random.rand(100, 8)  # Dummy feature data
#
# File c:\Users\Daydreamer\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\wrappers\scikit_learn.py:218, in KerasClassifier.__init__(self, build_fn, **sk_params)
# ...
